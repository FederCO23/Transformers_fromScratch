# %% [markdown]
# # Chapter 13 — Skip Connections
#
# > **Status:** Planned — not yet implemented.
#
# ## What This Notebook Covers
#
# Residual connections and why they matter. Covers how skip connections enable gradient flow in deep networks, the pre-norm vs post-norm pattern, and their role in transformer stability.
#
# ---
#
# ## Delivery Checklist
#
# - [ ] Original explanation in my own words
# - [ ] Runnable PyTorch implementation
# - [ ] Reusable module extracted to src/transformer_book_lab/ (if warranted)
# - [ ] Unit tests in 	ests/
# - [ ] Final exercise
# - [ ] Optional extensions

# %%
# TODO: implement chapter content
