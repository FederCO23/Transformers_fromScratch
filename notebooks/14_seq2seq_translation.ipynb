# %% [markdown]
# # Chapter 14 — Seq2Seq Translation (RNN Baseline)
#
# > **Status:** Planned — not yet implemented.
#
# ## What This Notebook Covers
#
# Building a sequence-to-sequence translation model with an LSTM encoder–decoder. This RNN baseline motivates why attention and transformers are needed.
#
# ---
#
# ## Delivery Checklist
#
# - [ ] Original explanation in my own words
# - [ ] Runnable PyTorch implementation
# - [ ] Reusable module extracted to src/transformer_book_lab/ (if warranted)
# - [ ] Unit tests in 	ests/
# - [ ] Final exercise
# - [ ] Optional extensions

# %%
# TODO: implement chapter content
