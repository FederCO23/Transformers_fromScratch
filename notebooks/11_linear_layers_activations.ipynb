# %% [markdown]
# # Chapter 11 — Linear Layers and Activations
#
# > **Status:** Planned — not yet implemented.
#
# ## What This Notebook Covers
#
# Feed-forward sub-layer design. Covers the two-layer FFN in the original transformer, activation functions (ReLU, GELU, SiLU/SwiGLU), and the gated variants used in modern LLMs.
#
# ---
#
# ## Delivery Checklist
#
# - [ ] Original explanation in my own words
# - [ ] Runnable PyTorch implementation
# - [ ] Reusable module extracted to src/transformer_book_lab/ (if warranted)
# - [ ] Unit tests in 	ests/
# - [ ] Final exercise
# - [ ] Optional extensions

# %%
# TODO: implement chapter content
