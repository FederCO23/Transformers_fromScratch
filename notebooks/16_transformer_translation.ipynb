# %% [markdown]
# # Chapter 16 — Full Transformer Translation
#
# > **Status:** Planned — not yet implemented.
#
# ## What This Notebook Covers
#
# Assembling all building blocks into a complete encoder–decoder transformer for translation. Covers the full training loop, label smoothing, and inference with greedy/beam search.
#
# ---
#
# ## Delivery Checklist
#
# - [ ] Original explanation in my own words
# - [ ] Runnable PyTorch implementation
# - [ ] Reusable module extracted to src/transformer_book_lab/ (if warranted)
# - [ ] Unit tests in 	ests/
# - [ ] Final exercise
# - [ ] Optional extensions

# %%
# TODO: implement chapter content
