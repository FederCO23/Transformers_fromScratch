# %% [markdown]
# # Chapter 17 — Decoder-Only Text Generation
#
# > **Status:** Planned — not yet implemented.
#
# ## What This Notebook Covers
#
# Building a GPT-style decoder-only transformer. Covers causal self-attention, autoregressive generation, temperature sampling, and top-k/top-p (nucleus) sampling.
#
# ---
#
# ## Delivery Checklist
#
# - [ ] Original explanation in my own words
# - [ ] Runnable PyTorch implementation
# - [ ] Reusable module extracted to src/transformer_book_lab/ (if warranted)
# - [ ] Unit tests in 	ests/
# - [ ] Final exercise
# - [ ] Optional extensions

# %%
# TODO: implement chapter content
