# %% [markdown]
# # Chapter 12 — Mixture of Experts (MoE)
#
# > **Status:** Planned — not yet implemented.
#
# ## What This Notebook Covers
#
# Sparse model scaling via expert routing. Covers the MoE architecture, top-k routing, load balancing, and how models like Mixtral use MoE to increase capacity without proportional compute.
#
# ---
#
# ## Delivery Checklist
#
# - [ ] Original explanation in my own words
# - [ ] Runnable PyTorch implementation
# - [ ] Reusable module extracted to src/transformer_book_lab/ (if warranted)
# - [ ] Unit tests in 	ests/
# - [ ] Final exercise
# - [ ] Optional extensions

# %%
# TODO: implement chapter content
