# %% [markdown]
# # Chapter 15 — Seq2Seq + Attention Translation
#
# > **Status:** Planned — not yet implemented.
#
# ## What This Notebook Covers
#
# Augmenting the RNN seq2seq model with Bahdanau attention. Shows the improvement over the vanilla seq2seq baseline and builds intuition for transformer attention.
#
# ---
#
# ## Delivery Checklist
#
# - [ ] Original explanation in my own words
# - [ ] Runnable PyTorch implementation
# - [ ] Reusable module extracted to src/transformer_book_lab/ (if warranted)
# - [ ] Unit tests in 	ests/
# - [ ] Final exercise
# - [ ] Optional extensions

# %%
# TODO: implement chapter content
