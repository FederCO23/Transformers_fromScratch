# %% [markdown]
# # Chapter 8 — Multi-Latent Attention (MLA)
#
# > **Status:** Planned — not yet implemented.
#
# ## What This Notebook Covers
#
# DeepSeek's Multi-Latent Attention — a KV-cache compression technique. Covers how low-rank joint compression of keys and values reduces inference memory without sacrificing quality.
#
# ---
#
# ## Delivery Checklist
#
# - [ ] Original explanation in my own words
# - [ ] Runnable PyTorch implementation
# - [ ] Reusable module extracted to src/transformer_book_lab/ (if warranted)
# - [ ] Unit tests in 	ests/
# - [ ] Final exercise
# - [ ] Optional extensions

# %%
# TODO: implement chapter content
