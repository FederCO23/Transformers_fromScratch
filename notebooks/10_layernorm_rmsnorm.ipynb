# %% [markdown]
# # Chapter 10 — LayerNorm and RMSNorm
#
# > **Status:** Planned — not yet implemented.
#
# ## What This Notebook Covers
#
# Normalization layers inside transformers. Covers why layer normalization is needed, Pre-LN vs Post-LN placement, and RMSNorm (used in LLaMA/Mistral) as a simpler alternative.
#
# ---
#
# ## Delivery Checklist
#
# - [ ] Original explanation in my own words
# - [ ] Runnable PyTorch implementation
# - [ ] Reusable module extracted to src/transformer_book_lab/ (if warranted)
# - [ ] Unit tests in 	ests/
# - [ ] Final exercise
# - [ ] Optional extensions

# %%
# TODO: implement chapter content
